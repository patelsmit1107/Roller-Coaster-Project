# %% [markdown]
# ## **Step 0 : Imports and Reading Data**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')

# %%
df=pd.read_csv("/content/coaster_db.csv")

# %% [markdown]
# ## **Step 1: Dtata Understanding**
#
#
# *   Dataframe shape
# *   head and tail
# *   dtypes
# * describe
# * info

# %%
df.shape #it wil give how many rows and columns are in data set.
# Out:
# (1087, 56)

# %%
df.columns #gives all columns name
# Out:
# Index(['coaster_name', 'Length', 'Speed', 'Location', 'Status', 'Opening date',
#        'Type', 'Manufacturer', 'Height restriction', 'Model', 'Height',
#        'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
#        'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
#        'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
#        'Track layout', 'Fastrack available', 'Soft opening date.1',
#        'Closing date', 'Opened', 'Replaced by', 'Website',
#        'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
#        'Single rider line available', 'Restraint Style',
#        'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
#        'year_introduced', 'latitude', 'longitude', 'Type_Main',
#        'opening_date_clean', 'speed1', 'speed2', 'speed1_value', 'speed1_unit',
#        'speed_mph', 'height_value', 'height_unit', 'height_ft',
#        'Inversions_clean', 'Gforce_clean'],
# ...

# %%
# To show first n entries in dataset we use df.head(n) defult value of n is 5
df.head()
# Out:
#                              coaster_name          Length             Speed  \
# 0                      Switchback Railway  600 ft (180 m)  6 mph (9.7 km/h)
# 1                       Flip Flap Railway             NaN               NaN
# 2  Switchback Railway (Euclid Beach Park)             NaN               NaN
# 3            Loop the Loop (Coney Island)             NaN               NaN
# 4            Loop the Loop (Young's Pier)             NaN               NaN
#
#                          Location   Status   Opening date   Type  \
# 0                    Coney Island  Removed  June 16, 1884   Wood
# 1                   Sea Lion Park  Removed           1895   Wood
# 2  Cleveland, Ohio, United States   Closed            NaN  Other
# 3                           Other  Removed           1901  Steel
# 4                           Other  Removed           1901  Steel
#
#              Manufacturer Height restriction        Model  ...  speed1  \
# ...

# %%
#To show last n entries in dataset we use df.tail(n) defult value of n is 5
df.tail()
# Out:
#                         coaster_name                Length  \
# 1082         American Dreier Looping    3,444 ft (1,050 m)
# 1083       Pantheon (roller coaster)    3,328 ft (1,014 m)
# 1084       Tron Lightcycle Power Run  3,169.3 ft (966.0 m)
# 1085                         Tumbili        770 ft (230 m)
# 1086  Wonder Woman Flight of Courage    3,300 ft (1,000 m)
#
#                         Speed                    Location              Status  \
# 1082         53 mph (85 km/h)                       Other                 NaN
# 1083        73 mph (117 km/h)  Busch Gardens Williamsburg  Under construction
# 1084  59.3[1] mph (95.4 km/h)                       Other                 NaN
# 1085         34 mph (55 km/h)              Kings Dominion  Under construction
# 1086         58 mph (93 km/h)    Six Flags Magic Mountain  Under construction
#
#        Opening date                                  Type  \
# 1082            NaN                                 Steel
# ...

# %%
# To know which data types our dataset contain we use df.dtype()
df.dtypes
# Out:
# coaster_name                      object
# Length                            object
# Speed                             object
# Location                          object
# Status                            object
# Opening date                      object
# Type                              object
# Manufacturer                      object
# Height restriction                object
# Model                             object
# Height                            object
# Inversions                       float64
# Lift/launch system                object
# Cost                              object
# Trains                            object
# Park section                      object
# Duration                          object
# Capacity                          object
# G-force                           object
# Designer                          object
# Max vertical angle                object
# Drop                              object
# Soft opening date                 object
# ...

# %%
# df.describe() function will give all statistical information of columns present in dataset like mean,median,max etc..
df.describe()
# Out:
#        Inversions  year_introduced    latitude   longitude  speed1_value  \
# count  932.000000      1087.000000  812.000000  812.000000    937.000000
# mean     1.547210      1994.986201   38.373484  -41.595373     53.850374
# std      2.114073        23.475248   15.516596   72.285227     23.385518
# min      0.000000      1884.000000  -48.261700 -123.035700      5.000000
# 25%      0.000000      1989.000000   35.031050  -84.552200     40.000000
# 50%      0.000000      2000.000000   40.289800  -76.653600     50.000000
# 75%      3.000000      2010.000000   44.799600    2.778100     63.000000
# max     14.000000      2022.000000   63.230900  153.426500    240.000000
#
#         speed_mph  height_value   height_ft  Inversions_clean  Gforce_clean
# count  937.000000    965.000000  171.000000       1087.000000    362.000000
# mean    48.617289     89.575171  101.996491          1.326587      3.824006
# std     16.678031    136.246444   67.329092          2.030854      0.989998
# ...

# %%
# To know information reagrding dataset we use df.info()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1087 entries, 0 to 1086
# Data columns (total 56 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   coaster_name                   1087 non-null   object
#  1   Length                         953 non-null    object
#  2   Speed                          937 non-null    object
#  3   Location                       1087 non-null   object
#  4   Status                         874 non-null    object
#  5   Opening date                   837 non-null    object
#  6   Type                           1087 non-null   object
#  7   Manufacturer                   1028 non-null   object
#  8   Height restriction             831 non-null    object
#  9   Model                          744 non-null    object
#  10  Height                         965 non-null    object
#  11  Inversions                     932 non-null    float64
# ...

# %%
df['Speed'].describe()
# Out:
# count                  937
# unique                 243
# top       50 mph (80 km/h)
# freq                    63
# Name: Speed, dtype: object

# %% [markdown]
# ## **Step 2: Data Preperation**
#
# * Checking null values
# * Droping ireelevent columns and rows
# * Renaming Columns
# * Feature Creation

# %%
# for checking null values we use df.isnull().sum()
df.isnull().sum()
# Out:
# coaster_name                        0
# Length                            134
# Speed                             150
# Location                            0
# Status                            213
# Opening date                      250
# Type                                0
# Manufacturer                       59
# Height restriction                256
# Model                             343
# Height                            122
# Inversions                        155
# Lift/launch system                292
# Cost                              705
# Trains                            369
# Park section                      600
# Duration                          322
# Capacity                          512
# G-force                           725
# Designer                          509
# Max vertical angle                730
# Drop                              593
# Soft opening date                 991
# Fast Lane available              1018
# Replaced                          914
# ...

# %%
#removing un wanted columns
df=df[['coaster_name','Location','Status','Manufacturer','year_introduced','latitude','longitude','Type_Main','opening_date_clean','speed_mph','height_ft','Inversions_clean','Gforce_clean']].copy() #.copy() means it is new data set

# %%
df.shape #we see that columns are deleted from datase
# Out:
# (1087, 13)

# %%
df.dtypes
# Out:
# coaster_name           object
# Location               object
# Status                 object
# Manufacturer           object
# year_introduced         int64
# latitude              float64
# longitude             float64
# Type_Main              object
# opening_date_clean     object
# speed_mph             float64
# height_ft             float64
# Inversions_clean        int64
# Gforce_clean          float64
# dtype: object

# %%
#change opening_date_clean to datetime
df['opening_date_clean']=pd.to_datetime(df['opening_date_clean'])

# %%
df.dtypes #see data type of opening_date_clean is changed
# Out:
# coaster_name                  object
# Location                      object
# Status                        object
# Manufacturer                  object
# year_introduced                int64
# latitude                     float64
# longitude                    float64
# Type_Main                     object
# opening_date_clean    datetime64[ns]
# speed_mph                    float64
# height_ft                    float64
# Inversions_clean               int64
# Gforce_clean                 float64
# dtype: object

# %%
#rename columns
df=df.rename(columns={'coaster_name':'Coaster_Name',
            'year_introduced':'Year_Introduced',
            'opening_date_clean':'Opening_Date_Clean',
            'speed_mph' : 'Speed_mph',
             'height_ft': 'Height_ft',
              'Inversions_clean':'Inversions',
               'Gforce_clean':'Gforce' })

# %%
#check null values
df.isna().sum()
# Out:
# Coaster_Name            0
# Location                0
# Status                213
# Manufacturer           59
# Year_Introduced         0
# latitude              275
# longitude             275
# Type_Main               0
# Opening_Date_Clean    250
# Speed_mph             150
# Height_ft             916
# Inversions              0
# Gforce                725
# dtype: int64

# %%
#cheking duplicate data
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1082    False
# 1083    False
# 1084    False
# 1085    False
# 1086    False
# Length: 1087, dtype: bool

# %%
df.loc[df.duplicated(subset=['Coaster_Name'])].head(6)# there will be 97 duplicates in our data set
# Out:
#                           Coaster_Name             Location     Status  \
# 43               Crystal Beach Cyclone   Crystal Beach Park    Removed
# 60                         Derby Racer         Revere Beach    Removed
# 61         Blue Streak (Conneaut Lake)   Conneaut Lake Park     Closed
# 167      Big Thunder Mountain Railroad                Other        NaN
# 237  Thunder Run (Canada's Wonderland)  Canada's Wonderland  Operating
# 239                          La Vibora                Other        NaN
#
#                                           Manufacturer  Year_Introduced  \
# 43                                  Traver Engineering             1927
# 60                                      Fred W. Pearce             1937
# 61                                                 NaN             1938
# 167  Arrow Development (California and Florida)Dyna...             1980
# 237                                         Mack Rides             1986
# ...

# %%
#remove duplicate
df.columns
# Out:
# Index(['Coaster_Name', 'Location', 'Status', 'Manufacturer', 'Year_Introduced',
#        'latitude', 'longitude', 'Type_Main', 'Opening_Date_Clean', 'Speed_mph',
#        'Height_ft', 'Inversions', 'Gforce'],
#       dtype='object')

# %%
df.duplicated(subset=['Coaster_Name','Location','Opening_Date_Clean']).sum() #tere will be 97 duplicated
# Out:
# 97

# %%
df.loc[~df.duplicated(subset=['Coaster_Name','Location','Opening_Date_Clean'])].head() #this are not duplicated columnswe gor by usinf(~)inverse of duplicated
# Out:
#                              Coaster_Name                        Location  \
# 0                      Switchback Railway                    Coney Island
# 1                       Flip Flap Railway                   Sea Lion Park
# 2  Switchback Railway (Euclid Beach Park)  Cleveland, Ohio, United States
# 3            Loop the Loop (Coney Island)                           Other
# 4            Loop the Loop (Young's Pier)                           Other
#
#     Status            Manufacturer  Year_Introduced  latitude  longitude  \
# 0  Removed  LaMarcus Adna Thompson             1884   40.5740   -73.9780
# 1  Removed            Lina Beecher             1895   40.5780   -73.9790
# 2   Closed                     NaN             1896   41.5800   -81.5700
# 3  Removed          Edwin Prescott             1901   40.5745   -73.9780
# 4  Removed          Edwin Prescott             1901   39.3538   -74.4342
#
#   Type_Main Opening_Date_Clean  Speed_mph  Height_ft  Inversions  Gforce
# ...

# %%
df=df.loc[~df.duplicated(subset=['Coaster_Name','Location','Opening_Date_Clean'])].reset_index(drop=True).copy() #changed index

# %%
df.shape #so we clean our data and we have 990 unique values
# Out:
# (990, 13)

# %% [markdown]
# ## **Step 3: Feature Understanding**
#
# (Univariate analysis)
#
#  * Plotting Feature Distribution
#
#   * Histogram
#
#   * KDE
#
#   * Boxplot

# %%
ax= df['Year_Introduced'].value_counts() \
.head(10)\
.plot(kind='bar',title='Top Years Costers Intoduced',color='green')
plt.xlabel('Year Introduced')
plt.ylabel('Count')
ax.grid(False)
plt.gca().set_facecolor('#99ff99')
plt.show()

# %%
ax=df['Speed_mph'].plot(kind='hist',title='Coster Speed (mph)',color='green')
plt.xlabel('Speed (mph)')
ax.grid(False)
plt.gca().set_facecolor('#99ff99')
plt.show()

# %%
ax=df['Speed_mph'].plot(kind='kde',title='Coster Speed (mph)',color='green')
plt.xlabel('Speed (mph)')
ax.grid(False)
plt.gca().set_facecolor('#99ff99')
plt.show()

# %% [markdown]
# ##**Step 4:Feature Relationship**
#
# * Scatterplot
#
# * Heatmap corelation
#
# * Pairplot
#
# * Groupby comparisions

# %%
ax=df.plot(kind='scatter',
        x='Speed_mph',
        y='Height_ft',
        title='Coster speed vs. Height',color='green')
ax.grid(False)
plt.gca().set_facecolor('#99ff99')
plt.show()

# %%
df.columns
# Out:
# Index(['Coaster_Name', 'Location', 'Status', 'Manufacturer', 'Year_Introduced',
#        'latitude', 'longitude', 'Type_Main', 'Opening_Date_Clean', 'Speed_mph',
#        'Height_ft', 'Inversions', 'Gforce'],
#       dtype='object')

# %%
ax=sns.scatterplot(x='Speed_mph',y='Height_ft',hue='Year_Introduced',data=df)
plt.title("Coster speed vs. Height'")
ax.grid(False)
plt.gca().set_facecolor('#99ff99')
plt.show()

# %%
#to compare multiple feature seaborn has built in function pairplot()ax
ax=sns.pairplot(data=df,vars=['Year_Introduced','Speed_mph','Height_ft','Height_ft','Gforce'],hue='Type_Main')
plt.show()

# %%
# find corelation
df_corr=df[['Year_Introduced','Speed_mph','Height_ft','Height_ft','Gforce']].dropna().corr() #dropna()-drop all null values,corr(corelation between diffrent features)

# %%
sns.heatmap(df_corr,annot=True)
plt.show()

# %% [markdown]
# ## **Step 5: Ask Question about data**

# %%
df.head()
# Out:
#                              Coaster_Name                        Location  \
# 0                      Switchback Railway                    Coney Island
# 1                       Flip Flap Railway                   Sea Lion Park
# 2  Switchback Railway (Euclid Beach Park)  Cleveland, Ohio, United States
# 3            Loop the Loop (Coney Island)                           Other
# 4            Loop the Loop (Young's Pier)                           Other
#
#     Status            Manufacturer  Year_Introduced  latitude  longitude  \
# 0  Removed  LaMarcus Adna Thompson             1884   40.5740   -73.9780
# 1  Removed            Lina Beecher             1895   40.5780   -73.9790
# 2   Closed                     NaN             1896   41.5800   -81.5700
# 3  Removed          Edwin Prescott             1901   40.5745   -73.9780
# 4  Removed          Edwin Prescott             1901   39.3538   -74.4342
#
#   Type_Main Opening_Date_Clean  Speed_mph  Height_ft  Inversions  Gforce
# ...

# %% [markdown]
# What are the loction with the fastest roller costers(minimum 10 l0cation)?

# %%
ax=df.query("Location != 'Other'" )\
  .groupby('Location')['Speed_mph']\
  .agg(['mean','count'])\
  .query('count >= 10')\
  .sort_values('mean')['mean']\
  .plot(kind='barh',title='Average Coast Speed By Location',color='green',figsize=(12,5))
plt.xlabel('Average Coaster Speed')
ax.grid(False)
plt.gca().set_facecolor('#99ff99') #change background color of chart
plt.show()

  #query is used for filtering it will gives data where location is not equal to other for better analysis
  #we group by location and speed based on speed
  #aggregation function return mean,count of the coulumns
  #again we filter the data where count is more than 10
  #and we sort the values by mean
